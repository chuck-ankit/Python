# %% [markdown]
# # Diffrencr between fit(),transform(),fit_transorm() and predict methods in scikit-lern.
#
#
# Life cycle of data science :
#
# EDA -> FE -> FS ->Model Cretion -> Model Deployment
#
# Data Preprocessing => Transformers (E.g Standard Scaler. Minmax Scaler, IMputer)
#
# Model Training => Linear Regression,Logist, Decision Trees, Random Forest, AdaBoast
#
#
# ![image.png](attachment:image.png)
